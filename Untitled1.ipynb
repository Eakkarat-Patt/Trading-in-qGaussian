# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Data/sp500_MinLogReturn.csv')

# %%
df
# Out:
#             Date  08:31:00  08:32:00  08:33:00  08:34:00  08:35:00  08:36:00  \
# 0     2011-11-07   1251.93   1252.49   1253.93   1252.85   1254.22   1254.93
# 1     2011-11-08   1266.27   1265.97   1266.05   1266.88   1266.97   1265.50
# 2     2011-11-09   1259.73   1253.37   1249.97   1246.95   1248.12   1247.81
# 3     2011-11-10   1238.95   1241.79   1244.83   1245.10   1243.62   1242.53
# 4     2011-11-11   1250.69   1254.77   1256.84   1256.86   1255.45   1255.97
# ...          ...       ...       ...       ...       ...       ...       ...
# 2501  2021-11-24   4666.99   4666.24   4663.66   4662.87   4666.46   4669.62
# 2502  2021-11-29   4653.46   4651.75   4646.27   4644.88   4644.38   4643.22
# 2503  2021-11-30   4624.60   4624.62   4632.30   4631.97   4631.08   4626.96
# 2504  2021-12-01   4619.66   4615.80   4614.62   4614.70   4612.27   4612.07
# 2505  2021-12-02   4519.69   4517.28   4519.89   4517.11   4511.70   4518.98
#
# ...

# %%
df = df.drop('Date', axis=1)

# %%
df = df.to_numpy()

# %%
df.shape
# Out:
# (2506, 411)

# %%
def logR(arr):
    logR = np.zeros([2506,411])
    for i in range(1, 411):
        logR[:, i] = np.log(arr[:, i]/arr[:, i-1])
    return logR

# %%
logR = logR(df)

# %%
logR.shape
# Out:
# (2506, 410)

# %%
logR = logR[:,1:]

# %%
logR = logR.reshape(1027460, 1)

# %%
pd.DataFrame(logR).to_csv('intra D log return.csv', header=None, index=None)

# %%
# Out:
# array([[ 4.47209341e-04,  1.14904937e-03, -8.61663223e-04, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-2.36944367e-04,  6.31906541e-05,  6.55367523e-04, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-5.06148866e-03, -2.71637260e-03, -2.41898136e-03, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        ...,
#        [ 4.32468900e-06,  1.65929959e-03, -7.12414470e-05, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-8.35908601e-04, -2.55676341e-04,  1.73360551e-05, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [-5.33364625e-04,  5.77614468e-04, -6.15248443e-04, ...,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])
